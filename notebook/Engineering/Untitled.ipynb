# %%
# !pip install python-dotenv minio boto3 SQLAlchemy pandas psycopg2-binary
# Out:
# ...
#      |████████████████████████████████| 93 kB 249 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 139 kB 5.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.0 MB 164 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.3 MB 16.2 MB/s eta 0:00:01     |███████▌                        | 532 kB 16.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 13.5 MB 180 kB/s eta 0:00:01    |█▉                              | 768 kB 5.9 MB/s eta 0:00:03     |████▉                           | 2.0 MB 5.9 MB/s eta 0:00:02     |█████                           | 2.1 MB 5.9 MB/s eta 0:00:02     |████████████████████▋           | 8.7 MB 5.0 MB/s eta 0:00:01     |█████████████████████████       | 10.5 MB 1.3 MB/s eta 0:00:03��███████████████   | 12.2 MB 1.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 84 kB 334 kB/s eta 0:00:01
# ...

# %%
# %run ./scripts/01_etl.py
# Out:
# Extraindo tabela pequena: clientes
# ✅ Salvou: data/clientes.csv (3 linhas)
# Extraindo tabela pequena: pedido
# ✅ Salvou: data/pedido.csv (3 linhas)
# Extraindo stgPedidos_01: chave de 1 até 1000000
# ✅ Salvou: data/stgPedidos_01.csv (0 linhas)
# Extraindo stgPedidos_02: chave de 1000001 até 2000000
# ✅ Salvou: data/stgPedidos_02.csv (2 linhas)
# Extraindo stgPedidos_03: chave de 2000001 até 3000000
# ✅ Salvou: data/stgPedidos_03.csv (1 linhas)
# Extraindo stgPedidos_04: chave de 3000001 até 4000000
# ✅ Salvou: data/stgPedidos_04.csv (0 linhas)
# Extraindo stgPedidos_05: chave de 4000001 até 5000000
# ✅ Salvou: data/stgPedidos_05.csv (2 linhas)
# Extraindo stgPedidos_06: chave de 5000001 até 6000000
# ✅ Salvou: data/stgPedidos_06.csv (1 linhas)
# Extraindo stgPedidos_07: chave de 6000001 até 7000000
# ✅ Salvou: data/stgPedidos_07.csv (2 linhas)
# Extraindo stgPedidos_08: chave de 7000001 até 8000000
# ✅ Salvou: data/stgPedidos_08.csv (1 linhas)
# ...

# %%
# %run ./scripts/02_upload.py

# %%
# %run ./scripts/03_bronze.py
